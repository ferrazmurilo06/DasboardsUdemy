# %%
import pandas as pd
import matplotlib as plt

# %%
data = {
    'Nome': ['Alice', 'Murilo', 'João', 'Coronel', 'Major'],
    'Idade': [30, 22, 19, 50, 65],
    'Cargo': ['Gerente', 'Analista', 'Analista', 'CEO', 'Coordenador'],
    'Salario': [10000, 1250, 1250, 60000, 40000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Nome  Idade        Cargo  Salario
# 0    Alice     30      Gerente    10000
# 1   Murilo     22     Analista     1250
# 2     João     19     Analista     1250
# 3  Coronel     50          CEO    60000
# 4    Major     65  Coordenador    40000

# %%
df.head(2)
# Out:
#      Nome  Idade     Cargo  Salario
# 0   Alice     30   Gerente    10000
# 1  Murilo     22  Analista     1250

# %%
df.tail(2)
# Out:
#       Nome  Idade        Cargo  Salario
# 3  Coronel     50          CEO    60000
# 4    Major     65  Coordenador    40000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Nome     5 non-null      str
#  1   Idade    5 non-null      int64
#  2   Cargo    5 non-null      str
#  3   Salario  5 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#            Idade       Salario
# count   5.000000      5.000000
# mean   37.200000  22500.000000
# std    19.690099  26324.299611
# min    19.000000   1250.000000
# 25%    22.000000   1250.000000
# 50%    30.000000  10000.000000
# 75%    50.000000  40000.000000
# max    65.000000  60000.000000

# %%
df[df['Salario'] > 5000]
# Out:
#       Nome  Idade        Cargo  Salario
# 0    Alice     30      Gerente    10000
# 3  Coronel     50          CEO    60000
# 4    Major     65  Coordenador    40000

# %%
df.sort_values(by='Idade', ascending=True)
# Out:
#       Nome  Idade        Cargo  Salario
# 2     João     19     Analista     1250
# 1   Murilo     22     Analista     1250
# 0    Alice     30      Gerente    10000
# 3  Coronel     50          CEO    60000
# 4    Major     65  Coordenador    40000

# %%
df['Bônus'] = df['Salario'] * 0.1
df
# Out:
#       Nome  Idade        Cargo  Salario   Bônus
# 0    Alice     30      Gerente    10000  1000.0
# 1   Murilo     22     Analista     1250   125.0
# 2     João     19     Analista     1250   125.0
# 3  Coronel     50          CEO    60000  6000.0
# 4    Major     65  Coordenador    40000  4000.0

# %%
df.groupby('Cargo')['Salario'].mean()
# Out:
# Cargo
# Analista        1250.0
# CEO            60000.0
# Coordenador    40000.0
# Gerente        10000.0
# Name: Salario, dtype: float64

# %%
df.plot(
    kind='bar',
    x='Nome',
    y='Salario',
    title='Salário ds funcionários',
    rot=45
)
# Out:
# <Axes: title={'center': 'Salário ds funcionários'}, xlabel='Nome'>
