# %%
import pandas as pd

# %%
df = pd.read_excel("dados/campeonato_brasileiro.xlsx")
df
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0     Flamengo                10         7        2         1        22
# 1    Fortaleza                10         6        1         3        16
# 2        Vasco                10         5        3         2        18
# 3        Ceará                10         4        3         3        14
# 4  Corinthians                10         3        2         5        10
#
#    Gols_Contra  Saldo_de_Gols  Pontos
# 0           10             12      23
# 1           15              1      19
# 2           12              6      18
# 3           16             -2      15
# 4           20            -10      11

# %%
df.dtypes
# Out:
# Times                 str
# Partidas_Jogadas    int64
# Vitorias            int64
# Empates             int64
# Derrotas            int64
# Gols_Pro            int64
# Gols_Contra         int64
# Saldo_de_Gols       int64
# Pontos              int64
# dtype: object

# %%
df.describe()
# Out:
#        Partidas_Jogadas  Vitorias  Empates  Derrotas   Gols_Pro  Gols_Contra  \
# count               5.0  5.000000  5.00000   5.00000   5.000000     5.000000
# mean               10.0  5.000000  2.20000   2.80000  16.000000    14.600000
# std                 0.0  1.581139  0.83666   1.48324   4.472136     3.847077
# min                10.0  3.000000  1.00000   1.00000  10.000000    10.000000
# 25%                10.0  4.000000  2.00000   2.00000  14.000000    12.000000
# 50%                10.0  5.000000  2.00000   3.00000  16.000000    15.000000
# 75%                10.0  6.000000  3.00000   3.00000  18.000000    16.000000
# max                10.0  7.000000  3.00000   5.00000  22.000000    20.000000
#
#        Saldo_de_Gols     Pontos
# count       5.000000   5.000000
# mean        1.400000  17.200000
# std         8.294577   4.494441
# min       -10.000000  11.000000
# 25%        -2.000000  15.000000
# 50%         1.000000  18.000000
# 75%         6.000000  19.000000
# ...

# %%
df.head(2)
# Out:
#        Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0   Flamengo                10         7        2         1        22
# 1  Fortaleza                10         6        1         3        16
#
#    Gols_Contra  Saldo_de_Gols  Pontos
# 0           10             12      23
# 1           15              1      19

# %%
df.tail(2)
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 3        Ceará                10         4        3         3        14
# 4  Corinthians                10         3        2         5        10
#
#    Gols_Contra  Saldo_de_Gols  Pontos
# 3           16             -2      15
# 4           20            -10      11

# %% [markdown]
# # Análise de desempenho por time:

# %%
desempenho_info = df[['Times','Pontos', 'Vitorias', 'Saldo_de_Gols', 'Gols_Pro', 'Gols_Contra']].set_index('Times')
desempenho_info
# Out:
#              Pontos  Vitorias  Saldo_de_Gols  Gols_Pro  Gols_Contra
# Times
# Flamengo         23         7             12        22           10
# Fortaleza        19         6              1        16           15
# Vasco            18         5              6        18           12
# Ceará            15         4             -2        14           16
# Corinthians      11         3            -10        10           20

# %% [markdown]
# # Times com mais vitórias e menos vitórias

# %%
time_mais_vitoria = df[df['Vitorias'] == df['Vitorias'].max()]
time_mais_vitoria
# Out:
#       Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 0  Flamengo                10         7        2         1        22
#
#    Gols_Contra  Saldo_de_Gols  Pontos
# 0           10             12      23

# %%
time_menos_vitoria = df[df['Vitorias'] == df['Vitorias'].min()]
time_menos_vitoria
# Out:
#          Times  Partidas_Jogadas  Vitorias  Empates  Derrotas  Gols_Pro  \
# 4  Corinthians                10         3        2         5        10
#
#    Gols_Contra  Saldo_de_Gols  Pontos
# 4           20            -10      11

# %% [markdown]
# # Distribuição de Gol Pró

# %%
df['Gols_Pro'].value_counts()
# Out:
# Gols_Pro
# 22    1
# 16    1
# 18    1
# 14    1
# 10    1
# Name: count, dtype: int64

# %% [markdown]
# # Relação de gols pró e pontos:

# %%
correlacao = df['Gols_Pro'].corr(df['Pontos'])
correlacao
# Out:
# np.float64(0.9701612604547394)
