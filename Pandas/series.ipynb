# %%
import pandas as pd

# %%
dados = [10, 70, 80, 90, 560]
serie = pd.Series(dados)
serie
# Out:
# 0     10
# 1     70
# 2     80
# 3     90
# 4    560
# dtype: int64

# %%
type(serie)
# Out:
# pandas.Series

# %%
vendas_mensais = pd.Series(
    [4000, 5000, 6500, 45000, 3200, 10000, 9750, 40000, 5400, 2000, 12000, 24000],
    index=['janeiro', 'fevereiro', 'março', 'abril','maio', 'junho', 'julho', 'agosto', 'setembro', 'outubro', 'novembro', 'dezembro']
)

# %%
vendas_mensais
# Out:
# janeiro       4000
# fevereiro     5000
# março         6500
# abril        45000
# maio          3200
# junho        10000
# julho         9750
# agosto       40000
# setembro      5400
# outubro       2000
# novembro     12000
# dezembro     24000
# dtype: int64

# %%
media_vendas = vendas_mensais.mean()
media_vendas
# Out:
# np.float64(13904.166666666666)
