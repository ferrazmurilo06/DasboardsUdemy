# %%
import pandas as pd

# %%
dados = {
    'Nome': ['Alice', 'Bob', 'Charlie'],
    'Idade': [20, 22, 19],
    'Cidade': ['Fortaleza', 'Rio de Janeiro', 'Mossoró']
}

# %%
df = pd.DataFrame(dados)

# %%
df
# Out:
#       Nome  Idade          Cidade
# 0    Alice     20       Fortaleza
# 1      Bob     22  Rio de Janeiro
# 2  Charlie     19         Mossoró

# %%
df.head(1)
# Out:
#     Nome  Idade     Cidade
# 0  Alice     20  Fortaleza

# %%
df.tail(1)
# Out:
#       Nome  Idade   Cidade
# 2  Charlie     19  Mossoró
